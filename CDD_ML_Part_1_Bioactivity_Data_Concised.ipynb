# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /Users/yuka/opt/anaconda3/lib/python3.8/site-packages (0.10.4)
# Requirement already satisfied: urllib3 in /Users/yuka/opt/anaconda3/lib/python3.8/site-packages (from chembl_webresource_client) (1.25.11)
# Requirement already satisfied: requests-cache>=0.6.0 in /Users/yuka/opt/anaconda3/lib/python3.8/site-packages (from chembl_webresource_client) (0.6.4)
# Requirement already satisfied: requests>=2.18.4 in /Users/yuka/opt/anaconda3/lib/python3.8/site-packages (from chembl_webresource_client) (2.24.0)
# Requirement already satisfied: easydict in /Users/yuka/opt/anaconda3/lib/python3.8/site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: itsdangerous in /Users/yuka/opt/anaconda3/lib/python3.8/site-packages (from requests-cache>=0.6.0->chembl_webresource_client) (1.1.0)
# Requirement already satisfied: url-normalize>=1.4 in /Users/yuka/opt/anaconda3/lib/python3.8/site-packages (from requests-cache>=0.6.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yuka/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.18.4->chembl_webresource_client) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/yuka/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/yuka/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: six in /Users/yuka/opt/anaconda3/lib/python3.8/site-packages (from url-normalize>=1.4->requests-cache>=0.6.0->chembl_webresource_client) (1.15.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('pancreatic')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references           organism  \
# 0   [{'xref_id': 'P16233', 'xref_name': None, 'xre...       Homo sapiens
# 1                                                  []         Sus scrofa
# 2   [{'xref_id': 'P07998', 'xref_name': None, 'xre...       Homo sapiens
# 3   [{'xref_id': 'P61823', 'xref_name': None, 'xre...         Bos taurus
# 4   [{'xref_id': 'P04746', 'xref_name': None, 'xre...       Homo sapiens
# 5   [{'xref_id': 'P00689', 'xref_name': None, 'xre...  Rattus norvegicus
# 6   [{'xref_id': 'P00690', 'xref_name': None, 'xre...         Sus scrofa
# 7                                                  []       Mus musculus
# 8                                                  []         Sus scrofa
# 9                                                  []               None
# 10  [{'xref_id': 'Q9UNI1', 'xref_name': None, 'xre...       Homo sapiens
# 11  [{'xref_id': 'P50391', 'xref_name': None, 'xre...       Homo sapiens
# 12  [{'xref_id': 'Q63447', 'xref_name': None, 'xre...  Rattus norvegicus
# 13                                                 []       Homo sapiens
# 14                                                 []    Cavia porcellus
# 15                                                 []       Mus musculus
# 16  [{'xref_id': 'Q9NZJ5', 'xref_name': None, 'xre...       Homo sapiens
# 17                                                 []  Rattus norvegicus
# 18  [{'xref_id': 'P14555', 'xref_name': None, 'xre...       Homo sapiens
# 19  [{'xref_id': 'P19835', 'xref_name': None, 'xre...       Homo sapiens
# 20  [{'xref_id': 'P30122', 'xref_name': None, 'xre...         Bos taurus
# 21                                                 []       Homo sapiens
# 22                                                 []  Rattus norvegicus
# 23                                                 []       Homo sapiens
# 24                                                 []       Homo sapiens
#
#                                             pref_name  score  \
# 0                                   Pancreatic lipase   16.0
# 1                   Pancreatic triacylglycerol lipase   16.0
# 2                             Ribonuclease pancreatic   15.0
# 3                             Ribonuclease pancreatic   15.0
# 4                            Pancreatic alpha-amylase   13.0
# 5                            Pancreatic alpha-amylase   13.0
# 6                            Pancreatic alpha-amylase   13.0
# 7                                   Pancreatic islets   13.0
# 8                                 Pancreatic elastase   13.0
# 9                               Pancreatic beta cells   12.0
# 10                                         Elastase 1   11.0
# 11                     Neuropeptide Y receptor type 4   11.0
# 12                     Neuropeptide Y receptor type 4   11.0
# 13                Pancreatic lipase-related protein 2   11.0
# 14                Pancreatic lipase-related protein 2   11.0
# 15                     Neuropeptide Y receptor type 4   11.0
# 16  Eukaryotic translation initiation factor 2-alp...   10.0
# 17  Eukaryotic translation initiation factor 2-alp...   10.0
# 18                         Phospholipase A2 group IIA    9.0
# 19                               Cholesterol esterase    9.0
# 20                               Cholesterol esterase    9.0
# 21       Tumor-associated calcium signal transducer 2    9.0
# 22  STE20/SPS1-related proline-alanine-rich protei...    9.0
# 23       Receptor-type tyrosine-protein phosphatase U    6.0
# 24                         Secretory phospholipase A2    2.0
#
#     species_group_flag target_chembl_id  \
# 0                False       CHEMBL1812
# 1                False    CHEMBL1687677
# 2                False       CHEMBL5425
# 3                False       CHEMBL6091
# 4                False       CHEMBL2045
# 5                False       CHEMBL2699
# 6                False       CHEMBL5730
# 7                False     CHEMBL613588
# 8                False    CHEMBL2096984
# 9                False     CHEMBL614780
# 10               False       CHEMBL3000
# 11               False       CHEMBL4877
# 12               False       CHEMBL4827
# 13               False    CHEMBL2169728
# 14               False    CHEMBL2169729
# 15               False    CHEMBL4105736
# 16               False       CHEMBL6030
# 17               False    CHEMBL4105946
# 18               False       CHEMBL3474
# 19               False       CHEMBL3219
# 20               False       CHEMBL2988
# 21               False    CHEMBL3856163
# 22               False    CHEMBL4105808
# 23               False    CHEMBL1961785
# 24               False    CHEMBL4524005
#
#                                     target_components     target_type   tax_id
# 0   [{'accession': 'P16233', 'component_descriptio...  SINGLE PROTEIN   9606.0
# 1   [{'accession': 'P00591', 'component_descriptio...  SINGLE PROTEIN   9823.0
# 2   [{'accession': 'P07998', 'component_descriptio...  SINGLE PROTEIN   9606.0
# 3   [{'accession': 'P61823', 'component_descriptio...  SINGLE PROTEIN   9913.0
# 4   [{'accession': 'P04746', 'component_descriptio...  SINGLE PROTEIN   9606.0
# 5   [{'accession': 'P00689', 'component_descriptio...  SINGLE PROTEIN  10116.0
# 6   [{'accession': 'P00690', 'component_descriptio...  SINGLE PROTEIN   9823.0
# 7                                                  []          TISSUE  10090.0
# 8   [{'accession': 'P08419', 'component_descriptio...  PROTEIN FAMILY   9823.0
# 9                                                  []       CELL-LINE      NaN
# 10  [{'accession': 'Q9UNI1', 'component_descriptio...  SINGLE PROTEIN   9606.0
# 11  [{'accession': 'P50391', 'component_descriptio...  SINGLE PROTEIN   9606.0
# 12  [{'accession': 'Q63447', 'component_descriptio...  SINGLE PROTEIN  10116.0
# 13  [{'accession': 'P54317', 'component_descriptio...  SINGLE PROTEIN   9606.0
# 14  [{'accession': 'P81139', 'component_descriptio...  SINGLE PROTEIN  10141.0
# 15  [{'accession': 'Q61041', 'component_descriptio...  SINGLE PROTEIN  10090.0
# 16  [{'accession': 'Q9NZJ5', 'component_descriptio...  SINGLE PROTEIN   9606.0
# 17  [{'accession': 'Q9Z1Z1', 'component_descriptio...  SINGLE PROTEIN  10116.0
# 18  [{'accession': 'P14555', 'component_descriptio...  SINGLE PROTEIN   9606.0
# 19  [{'accession': 'P19835', 'component_descriptio...  SINGLE PROTEIN   9606.0
# 20  [{'accession': 'P30122', 'component_descriptio...  SINGLE PROTEIN   9913.0
# 21  [{'accession': 'P09758', 'component_descriptio...  SINGLE PROTEIN   9606.0
# 22  [{'accession': 'O88506', 'component_descriptio...  SINGLE PROTEIN  10116.0
# 23  [{'accession': 'Q92729', 'component_descriptio...  SINGLE PROTEIN   9606.0
# 24  [{'accession': 'Q5R387', 'component_descriptio...  PROTEIN FAMILY   9606.0

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (fifth entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL1812'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None        33970                  []    CHEMBL760716
# 1             None        37567                  []    CHEMBL760716
# 2             None        45912                  []    CHEMBL760716
#
#                                    assay_description assay_type  \
# 0  Compound was tested to inhibit pancreatic lipa...          B
# 1  Compound was tested to inhibit pancreatic lipa...          B
# 2  Compound was tested to inhibit pancreatic lipa...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
#
#    ... target_organism   target_pref_name target_tax_id text_value  toid  \
# 0  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 1  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 2  ...    Homo sapiens  Pancreatic lipase          9606       None  None
#
#    type  units    uo_units upper_value value
# 0  IC50     uM  UO_0000065        None  10.0
# 1  IC50     uM  UO_0000065        None  50.0
# 2  IC50     uM  UO_0000065        None  50.0
#
# [3 rows x 45 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_panc_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#    activity_comment  activity_id activity_properties assay_chembl_id  \
# 0              None        33970                  []    CHEMBL760716
# 1              None        37567                  []    CHEMBL760716
# 2              None        45912                  []    CHEMBL760716
# 3              None        52423                  []    CHEMBL760716
# 4              None        66565                  []    CHEMBL760716
# 5              None       262557                  []    CHEMBL856675
# 6              None       263947                  []    CHEMBL856675
# 7              None      2056957                  []    CHEMBL925170
# 8              None      2056958                  []    CHEMBL925170
# 9              None      2056965                  []    CHEMBL925170
# 10             None      2056966                  []    CHEMBL925170
# 11             None      2056969                  []    CHEMBL925170
# 12             None      2539013                  []    CHEMBL972810
# 13             None      3446482                  []   CHEMBL1244649
# 14             None     16825153                  []   CHEMBL3873815
# 15             None     16825154                  []   CHEMBL3873815
# 16             None     16825155                  []   CHEMBL3873815
# 17             None     17967968                  []   CHEMBL3995432
# 18             None     17967969                  []   CHEMBL3995432
# 19             None     18407182                  []   CHEMBL4151255
# 20             None     18407197                  []   CHEMBL4151255
# 21             None     18407198                  []   CHEMBL4151255
# 22             None     18407199                  []   CHEMBL4151255
# 23             None     18407200                  []   CHEMBL4151255
# 24             None     18407201                  []   CHEMBL4151255
# 25             None     18407202                  []   CHEMBL4151255
# 26             None     18407203                  []   CHEMBL4151255
# 27             None     18407204                  []   CHEMBL4151255
# 28             None     18407205                  []   CHEMBL4151255
# 29             None     18407206                  []   CHEMBL4151255
# 30             None     18407207                  []   CHEMBL4151255
# 31             None     18407208                  []   CHEMBL4151255
# 32             None     18407209                  []   CHEMBL4151255
# 33             None     18407210                  []   CHEMBL4151255
# 34             None     19172658                  []   CHEMBL4385278
# 35             None     19172659                  []   CHEMBL4385278
#
#                                     assay_description assay_type  \
# 0   Compound was tested to inhibit pancreatic lipa...          B
# 1   Compound was tested to inhibit pancreatic lipa...          B
# 2   Compound was tested to inhibit pancreatic lipa...          B
# 3   Compound was tested to inhibit pancreatic lipa...          B
# 4   Compound was tested to inhibit pancreatic lipa...          B
# 5   Compound was tested for inhibition of porcine ...          B
# 6   Compound was tested for inhibition of porcine ...          B
# 7                     Inhibition of pancreatic lipase          B
# 8                     Inhibition of pancreatic lipase          B
# 9                     Inhibition of pancreatic lipase          B
# 10                    Inhibition of pancreatic lipase          B
# 11                    Inhibition of pancreatic lipase          B
# 12  Inhibition of pancreatic lipase assessed as um...          B
# 13              Binding affinity to pancreatic lipase          B
# 14   Inhibition of pancreatic lipase (unknown origin)          B
# 15   Inhibition of pancreatic lipase (unknown origin)          B
# 16   Inhibition of pancreatic lipase (unknown origin)          B
# 17  Inhibition of human pancreatic lipase using 4-...          B
# 18  Inhibition of human pancreatic lipase using 4-...          B
# 19  Inhibition of human pancreatic lipase using em...          B
# 20  Inhibition of human pancreatic lipase using em...          B
# 21  Inhibition of human pancreatic lipase using em...          B
# 22  Inhibition of human pancreatic lipase using em...          B
# 23  Inhibition of human pancreatic lipase using em...          B
# 24  Inhibition of human pancreatic lipase using em...          B
# 25  Inhibition of human pancreatic lipase using em...          B
# 26  Inhibition of human pancreatic lipase using em...          B
# 27  Inhibition of human pancreatic lipase using em...          B
# 28  Inhibition of human pancreatic lipase using em...          B
# 29  Inhibition of human pancreatic lipase using em...          B
# 30  Inhibition of human pancreatic lipase using em...          B
# 31  Inhibition of human pancreatic lipase using em...          B
# 32  Inhibition of human pancreatic lipase using em...          B
# 33  Inhibition of human pancreatic lipase using em...          B
# 34  Inhibition of recombinant human PL expressed i...          B
# 35  Inhibition of recombinant human PL expressed i...          B
#
#    assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                     None                   None  BAO_0000190  BAO_0000357
# 1                     None                   None  BAO_0000190  BAO_0000357
# 2                     None                   None  BAO_0000190  BAO_0000357
# 3                     None                   None  BAO_0000190  BAO_0000357
# 4                     None                   None  BAO_0000190  BAO_0000357
# 5                     None                   None  BAO_0000190  BAO_0000357
# 6                     None                   None  BAO_0000190  BAO_0000357
# 7                     None                   None  BAO_0000190  BAO_0000357
# 8                     None                   None  BAO_0000190  BAO_0000357
# 9                     None                   None  BAO_0000190  BAO_0000357
# 10                    None                   None  BAO_0000190  BAO_0000357
# 11                    None                   None  BAO_0000190  BAO_0000357
# 12                    None                   None  BAO_0000190  BAO_0000357
# 13                    None                   None  BAO_0000190  BAO_0000357
# 14                    None                   None  BAO_0000190  BAO_0000357
# 15                    None                   None  BAO_0000190  BAO_0000357
# 16                    None                   None  BAO_0000190  BAO_0000357
# 17                    None                   None  BAO_0000190  BAO_0000357
# 18                    None                   None  BAO_0000190  BAO_0000357
# 19                    None                   None  BAO_0000190  BAO_0000357
# 20                    None                   None  BAO_0000190  BAO_0000357
# 21                    None                   None  BAO_0000190  BAO_0000357
# 22                    None                   None  BAO_0000190  BAO_0000357
# 23                    None                   None  BAO_0000190  BAO_0000357
# 24                    None                   None  BAO_0000190  BAO_0000357
# 25                    None                   None  BAO_0000190  BAO_0000357
# 26                    None                   None  BAO_0000190  BAO_0000357
# 27                    None                   None  BAO_0000190  BAO_0000357
# 28                    None                   None  BAO_0000190  BAO_0000357
# 29                    None                   None  BAO_0000190  BAO_0000357
# 30                    None                   None  BAO_0000190  BAO_0000357
# 31                    None                   None  BAO_0000190  BAO_0000357
# 32                    None                   None  BAO_0000190  BAO_0000357
# 33                    None                   None  BAO_0000190  BAO_0000357
# 34                    None                   None  BAO_0000190  BAO_0000219
# 35                    None                   None  BAO_0000190  BAO_0000219
#
#     ... target_organism   target_pref_name target_tax_id text_value  toid  \
# 0   ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 1   ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 2   ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 3   ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 4   ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 5   ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 6   ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 7   ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 8   ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 9   ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 10  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 11  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 12  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 13  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 14  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 15  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 16  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 17  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 18  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 19  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 20  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 21  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 22  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 23  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 24  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 25  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 26  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 27  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 28  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 29  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 30  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 31  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 32  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 33  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 34  ...    Homo sapiens  Pancreatic lipase          9606       None  None
# 35  ...    Homo sapiens  Pancreatic lipase          9606       None  None
#
#     type    units    uo_units upper_value  value
# 0   IC50       uM  UO_0000065        None   10.0
# 1   IC50       uM  UO_0000065        None   50.0
# 2   IC50       uM  UO_0000065        None   50.0
# 3   IC50       uM  UO_0000065        None   50.0
# 4   IC50       uM  UO_0000065        None   10.0
# 5   IC50  ug ml-1  UO_0000274        None    0.4
# 6   IC50  ug ml-1  UO_0000274        None    1.7
# 7   IC50       uM  UO_0000065        None   36.0
# 8   IC50       uM  UO_0000065        None   13.0
# 9   IC50       uM  UO_0000065        None  120.0
# 10  IC50       uM  UO_0000065        None   27.0
# 11  IC50       uM  UO_0000065        None  270.0
# 12  IC50  ug ml-1  UO_0000274        None   0.04
# 13  IC50       uM  UO_0000065        None   16.0
# 14  IC50       uM  UO_0000065        None  428.6
# 15  IC50       uM  UO_0000065        None  168.6
# 16  IC50       uM  UO_0000065        None   17.9
# 17  IC50       uM  UO_0000065        None    9.0
# 18  IC50       uM  UO_0000065        None    3.2
# 19  IC50       uM  UO_0000065        None   0.19
# 20  IC50       uM  UO_0000065        None   7.82
# 21  IC50       uM  UO_0000065        None  13.48
# 22  IC50       uM  UO_0000065        None    6.9
# 23  IC50       uM  UO_0000065        None   1.87
# 24  IC50       uM  UO_0000065        None   2.31
# 25  IC50       uM  UO_0000065        None   2.28
# 26  IC50       uM  UO_0000065        None   1.25
# 27  IC50       uM  UO_0000065        None   1.65
# 28  IC50       uM  UO_0000065        None   2.01
# 29  IC50       uM  UO_0000065        None    1.1
# 30  IC50       uM  UO_0000065        None   9.15
# 31  IC50       uM  UO_0000065        None   7.38
# 32  IC50       uM  UO_0000065        None  11.75
# 33  IC50       uM  UO_0000065        None  14.48
# 34  IC50       nM  UO_0000065        None    6.0
# 35  IC50       uM  UO_0000065        None   37.0
#
# [36 rows x 45 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  #else:
  #  bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1        CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 2        CHEMBL131051   CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)c1ccccc1
# 3        CHEMBL106126            Cc1c(C(C)C)c(=O)on1C(=O)N1CCC[C@H](C)C1
# 4        CHEMBL339297  COc1nn(-c2ccc(NC(=O)c3ccc(C(C)(C)C)cc3)cc2)c(=...
# 5        CHEMBL175247  CCCCCCCCCCC[C@@H](C[C@@H]1OC(=O)[C@H]1CCCCCC)O...
# 6        CHEMBL360443  C=C1O[C@@H](C[C@H](CCCCCCCCCCC)OC(=O)[C@H](CC(...
# 7        CHEMBL484853  CC(C)c1cc2c(c(O)c1O)[C@@]1(C(=O)O)CCCC(C)(C)[C...
# 8        CHEMBL218693  CC(C)c1cc2c(c(O)c1O)[C@@]13CCCC(C)(C)[C@@H]1C[...
# 9        CHEMBL263831  C/C=C/CCCC/C=C/C(=O)NC(CC1(O)C(=O)C2OC2C2OC21)...
# 10       CHEMBL254196  C/C=C/CCCC/C=C/C(=O)N[C@@H](C[C@@]1(O)C(=O)C2O...
# 11       CHEMBL253780  C/C=C/CCCC/C=C/C(=O)N[C@H](C[C@]1(O)C(=O)C2OC2...
# 12       CHEMBL175247  CCCCCCCCCCC[C@@H](C[C@@H]1OC(=O)[C@H]1CCCCCC)O...
# 13      CHEMBL1240685  C[C@@H](O)[C@@H](NC(=O)[C@@H](CCC(N)=O)NC(=O)C...
# 14      CHEMBL3893262       COc1cc2[nH]c3c4c(c(C)cc3c2cc1OC)OC(C)(C)C=C4
# 15      CHEMBL2323768         COc1ccc2[nH]c3c4c(c(C)cc3c2c1)OC(C)(C)C=C4
# 16       CHEMBL495873     CC(C)=CCCC1(C)C=Cc2c(c(C)cc3c2[nH]c2ccccc23)O1
# 17      CHEMBL4077903             C/C(=C\C[C@@]12C=C(CO)C[C@@H]1OC2=O)CO
# 18      CHEMBL4102155          COC(OC)C1=C[C@@]2(CC=C(C)C)C(=O)O[C@H]2C1
# 19       CHEMBL175247  CCCCCCCCCCC[C@@H](C[C@@H]1OC(=O)[C@H]1CCCCCC)O...
# 20      CHEMBL4160094  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 21      CHEMBL4170734  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 22      CHEMBL4175223  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 23      CHEMBL4167341  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 24      CHEMBL4163899  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 25      CHEMBL4168413  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 26      CHEMBL4160519  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 27      CHEMBL4164998  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 28      CHEMBL4165339  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 29      CHEMBL4173252  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 30      CHEMBL4168757  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 31      CHEMBL4176621  C#CCOC(=O)C/C(C=O)=C\CC1C(=C)CC[C@H]2C(C)(C)CC...
# 32      CHEMBL4172103  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 33      CHEMBL4161505    C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC=O
# 34       CHEMBL175247  CCCCCCCCCCC[C@@H](C[C@@H]1OC(=O)[C@H]1CCCCCC)O...
# 35      CHEMBL4471545  CS(=O)(=O)C(c1nnc(CNS(N)(=O)=O)o1)c1nc2ccc(-c3...
#
#    standard_value
# 0         10000.0
# 1         50000.0
# 2         50000.0
# 3         50000.0
# 4         10000.0
# 5             0.4
# 6             1.7
# 7         36000.0
# 8         13000.0
# 9        120000.0
# 10        27000.0
# 11       270000.0
# 12           0.04
# 13        16000.0
# 14       428600.0
# 15       168600.0
# 16        17900.0
# 17         9000.0
# 18         3200.0
# 19          190.0
# 20         7820.0
# 21        13480.0
# 22         6900.0
# 23         1870.0
# 24         2310.0
# 25         2280.0
# 26         1250.0
# 27         1650.0
# 28         2010.0
# 29         1100.0
# 30         9150.0
# 31         7380.0
# 32        11750.0
# 33        14480.0
# 34            6.0
# 35        37000.0

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1        CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 2        CHEMBL131051   CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)c1ccccc1
# 3        CHEMBL106126            Cc1c(C(C)C)c(=O)on1C(=O)N1CCC[C@H](C)C1
# 4        CHEMBL339297  COc1nn(-c2ccc(NC(=O)c3ccc(C(C)(C)C)cc3)cc2)c(=...
# 5        CHEMBL175247  CCCCCCCCCCC[C@@H](C[C@@H]1OC(=O)[C@H]1CCCCCC)O...
# 6        CHEMBL360443  C=C1O[C@@H](C[C@H](CCCCCCCCCCC)OC(=O)[C@H](CC(...
# 7        CHEMBL484853  CC(C)c1cc2c(c(O)c1O)[C@@]1(C(=O)O)CCCC(C)(C)[C...
# 8        CHEMBL218693  CC(C)c1cc2c(c(O)c1O)[C@@]13CCCC(C)(C)[C@@H]1C[...
# 9        CHEMBL263831  C/C=C/CCCC/C=C/C(=O)NC(CC1(O)C(=O)C2OC2C2OC21)...
# 10       CHEMBL254196  C/C=C/CCCC/C=C/C(=O)N[C@@H](C[C@@]1(O)C(=O)C2O...
# 11       CHEMBL253780  C/C=C/CCCC/C=C/C(=O)N[C@H](C[C@]1(O)C(=O)C2OC2...
# 12       CHEMBL175247  CCCCCCCCCCC[C@@H](C[C@@H]1OC(=O)[C@H]1CCCCCC)O...
# 13      CHEMBL1240685  C[C@@H](O)[C@@H](NC(=O)[C@@H](CCC(N)=O)NC(=O)C...
# 14      CHEMBL3893262       COc1cc2[nH]c3c4c(c(C)cc3c2cc1OC)OC(C)(C)C=C4
# 15      CHEMBL2323768         COc1ccc2[nH]c3c4c(c(C)cc3c2c1)OC(C)(C)C=C4
# 16       CHEMBL495873     CC(C)=CCCC1(C)C=Cc2c(c(C)cc3c2[nH]c2ccccc23)O1
# 17      CHEMBL4077903             C/C(=C\C[C@@]12C=C(CO)C[C@@H]1OC2=O)CO
# 18      CHEMBL4102155          COC(OC)C1=C[C@@]2(CC=C(C)C)C(=O)O[C@H]2C1
# 19       CHEMBL175247  CCCCCCCCCCC[C@@H](C[C@@H]1OC(=O)[C@H]1CCCCCC)O...
# 20      CHEMBL4160094  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 21      CHEMBL4170734  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 22      CHEMBL4175223  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 23      CHEMBL4167341  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 24      CHEMBL4163899  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 25      CHEMBL4168413  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 26      CHEMBL4160519  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 27      CHEMBL4164998  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 28      CHEMBL4165339  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 29      CHEMBL4173252  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 30      CHEMBL4168757  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 31      CHEMBL4176621  C#CCOC(=O)C/C(C=O)=C\CC1C(=C)CC[C@H]2C(C)(C)CC...
# 32      CHEMBL4172103  C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC(...
# 33      CHEMBL4161505    C=C1CC[C@H]2C(C)(C)CCC[C@]2(C)C1C/C=C(/C=O)CC=O
# 34       CHEMBL175247  CCCCCCCCCCC[C@@H](C[C@@H]1OC(=O)[C@H]1CCCCCC)O...
# 35      CHEMBL4471545  CS(=O)(=O)C(c1nnc(CNS(N)(=O)=O)o1)c1nc2ccc(-c3...
#
#    standard_value bioactivity_class
# 0         10000.0          inactive
# 1         50000.0          inactive
# 2         50000.0          inactive
# 3         50000.0          inactive
# 4         10000.0          inactive
# 5             0.4            active
# 6             1.7            active
# 7         36000.0          inactive
# 8         13000.0          inactive
# 9        120000.0          inactive
# 10        27000.0          inactive
# 11       270000.0          inactive
# 12           0.04            active
# 13        16000.0          inactive
# 14       428600.0          inactive
# 15       168600.0          inactive
# 16        17900.0          inactive
# 17         9000.0            active
# 18         3200.0          inactive
# 19          190.0          inactive
# 20         7820.0          inactive
# 21        13480.0            active
# 22         6900.0          inactive
# 23         1870.0               NaN
# 24         2310.0               NaN
# 25         2280.0               NaN
# 26         1250.0               NaN
# 27         1650.0               NaN
# 28         2010.0               NaN
# 29         1100.0               NaN
# 30         9150.0               NaN
# 31         7380.0               NaN
# 32        11750.0               NaN
# 33        14480.0               NaN
# 34            6.0               NaN
# 35        37000.0               NaN

# %% [markdown]
# Saves dataframe to CSV file

# %%
df4.to_csv('bioactivity_panc_data_preprocessed.csv', index=False)

# %%
! ls -l
# Out:
# total 1160
# -rw-r--r--@ 1 yuka  staff  116256 Jun 19 16:55 CDD_ML_Part_1_Bioactivity_Data_Concised.ipynb
# -rw-r--r--@ 1 yuka  staff  134088 Jun 19 15:52 CDD_ML_Part_1_bioactivity_data.ipynb
# -rw-r--r--@ 1 yuka  staff  226308 Jun 19 16:48 CDD_ML_Part_2_Exploratory_Data_Analysis.ipynb
# -rw-r--r--  1 yuka  staff   70334 Jun 19 15:25 bioactivity_coronavirus_data.csv
# -rw-r--r--  1 yuka  staff    9337 Jun 19 15:38 bioactivity_coronavirus_preprocessed_data.csv
# -rw-r--r--@ 1 yuka  staff    3320 Jun 19 16:55 bioactivity_panc_data_preprocessed.csv
# -rw-r--r--  1 yuka  staff   20027 Jun 19 16:54 bioactivity_panc_data_raw.csv

# %% [markdown]
# ---
